# %% [markdown]
# <a href="https://colab.research.google.com/github/subhashiitb/IITKGP-ML/blob/main/BasicsOfML/M1/S4/4.3/M1-S4-4.3.Multiple-Linear-Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Linear Regression
#
# In this notebook, we'll build a multiple regression model to predict `Housing` using an appropriate predictor variable.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
url = 'https://raw.githubusercontent.com/subhashiitb/IITKGP-ML/main/BasicsOfML/M1/S4/4.3/M1-S4-4.3.data.csv'
housing = pd.read_csv(url)
housing.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
